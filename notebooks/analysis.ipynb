# %% [markdown]
# # PriceSense analysis
# Randomized promotion experiment, targeting models, and policy value.

# %%
from pricesense.data import download, load
from pricesense.experiment import ab_summary
path = download()
df = load(path)
ab_summary(df)

# %%
from pricesense.analysis import run
results = run(path)
results
